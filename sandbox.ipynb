# %%
# Set autoreload libraries every time before executing
# %load_ext autoreload
# %autoreload 2

from utils.helper import get_data, get_fanatics
from utils.visualize import line_plot, line_plot_95_interval

# %%
# Change the date time to the date time of the pickle file you want to load
DATE = '241001'
TIME = '1707'
metrics= ['MEAN', 'STDEV', 'BIAS', 'ENLITE', 'SECTS', 'CON', 'CLUSTERING_COEFFICIENT', 'MEAN_INDEGREE','MEDIAN_INDEGREE', 'MODE_INDEGREE', 'MIN_INDEGREE', 'MAX_INDEGREE']
data_fanatics, data_no_fanatics = get_data(DATE, TIME)

fanatics_switch_min = get_fanatics(data_fanatics, data_no_fanatics, 'mean', 0.5)

# %%
metrics= ['MEAN']
line_plot_95_interval(fanatics_switch_min, metrics, DATE, TIME, export=True)

# %%
line_plot(fanatics_switch_min, metrics, DATE, TIME, export=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 line_plot(fanatics_switch_min, metrics, DATE, TIME, export=True)
#
# File d:\social-network\utils\visualize.py:208, in line_plot(data, metrics, date, time, export)
#     206         g.set_ylim(0, 17)
#     207     axs[i//4][i%4].set_title(f'{metric} vs. beta')
# --> 208     sns.move_legend(g, "upper right", title='# fanatics')
#     210 # Customization
#     211 plt.tight_layout()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\seaborn\utils.py:432, in move_legend(obj, loc, **kwargs)
#     430 if old_legend is None:
#     431     err = f"{obj} has no legend attached."
# --> 432     raise ValueError(err)
#     434 # Extract the components of the legend we need to reuse
#     435 # Import here to avoid a circular import
#     436 from seaborn._compat import get_legend_handles
#
# ValueError: Axes(0.125,0.653529;0.168478x0.226471) has no legend attached.
